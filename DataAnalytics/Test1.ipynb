# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

pd.set_option('display.mpl_style', 'default') # Make the graphs a bit prettier
plt.rcParams['figure.figsize'] = (15, 5)

# %%
mdata = pd.read_csv('all.csv', sep=',', encoding='latin1')
mdata[:3]
# Out:
#              model     kms                                                img  \
# 0           Flyer    51000  http://mco-s1-p.mlstatic.com/701221-MCO2070395...
# 1          Rivera   189000  http://mco-s2-p.mlstatic.com/626311-MCO2054988...
# 2   Otros Modelos    93374  http://mco-s2-p.mlstatic.com/905021-MCO2069998...
#
#                              title  \
# 0   Byd Flyer 1.1l Mt 1100cc 5p Aa
# 1        Buick Rivera At 3800cc 2p
# 2      Chevrolet Grand Vitara 2006
#
#                                                 link     price  year  \
# 0  http://articulo.tucarro.com.co/MCO-422820949-b...   7300000  2006
# 1  http://articulo.tucarro.com.co/MCO-421154714-b...  25000000  1980
# 2  http://articulo.tucarro.com.co/MCO-422791210-c...  32000000  2006
#
#          maker
# 0         BYD
# 1       Buick
# 2   Chevrolet

# %%
mdata['price'].plot()

# %%
maker = mdata['maker'].value_counts()
maker.plot(kind='bar')

# %%
e = mdata['maker'][:10]
print e[0]
print e[0] == ' BYD '
# Out:
#  BYD
# True
